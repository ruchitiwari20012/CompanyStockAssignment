# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Company Stock and Investment.csv')

# %%
df.head()
# Out:
#          Date  Oil Investments  Gold Investments  Comp Stock  \
# 0  31-12-2009         0.025417          0.000150    0.017354
# 1  04-01-2010         0.026830          0.001097    0.015565
# 2  05-01-2010         0.002699          0.001560    0.001729
# 3  06-01-2010         0.021688          0.006009   -0.015906
# 4  07-01-2010        -0.006256          0.000221   -0.001849
#
#    Other sharesInvestments
# 0                 0.006848
# 1                -0.004609
# 2                 0.005900
# 3                -0.018116
# 4                -0.017013

# %%
df.tail()
# Out:
#             Date  Oil Investments  Gold Investments  Comp Stock  \
# 1979  09-11-2017         0.005984          0.000623   -0.002043
# 1980  10-11-2017        -0.007173         -0.000389   -0.006880
# 1981  13-11-2017         0.000352         -0.004944   -0.004008
# 1982  14-11-2017        -0.019376         -0.002621   -0.015118
# 1983  15-11-2017        -0.007006          0.005963   -0.013190
#
#       Other sharesInvestments
# 1979                -0.003310
# 1980                -0.003348
# 1981                 0.003395
# 1982                 0.006793
# 1983                -0.008928

# %%
# Convert Month into Datetime
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date  Oil Investments  Gold Investments  Comp Stock  \
# 0 2009-12-31         0.025417          0.000150    0.017354
# 1 2010-04-01         0.026830          0.001097    0.015565
# 2 2010-05-01         0.002699          0.001560    0.001729
# 3 2010-06-01         0.021688          0.006009   -0.015906
# 4 2010-07-01        -0.006256          0.000221   -0.001849
#
#    Other sharesInvestments
# 0                 0.006848
# 1                -0.004609
# 2                 0.005900
# 3                -0.018116
# 4                -0.017013

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#             Oil Investments  Gold Investments  Comp Stock  \
# Date
# 2009-12-31         0.025417          0.000150    0.017354
# 2010-04-01         0.026830          0.001097    0.015565
# 2010-05-01         0.002699          0.001560    0.001729
# 2010-06-01         0.021688          0.006009   -0.015906
# 2010-07-01        -0.006256          0.000221   -0.001849
#
#             Other sharesInvestments
# Date
# 2009-12-31                 0.006848
# 2010-04-01                -0.004609
# 2010-05-01                 0.005900
# 2010-06-01                -0.018116
# 2010-07-01                -0.017013

# %%
df.describe()
# Out:
#        Oil Investments  Gold Investments   Comp Stock  Other sharesInvestments
# count      1984.000000       1984.000000  1984.000000              1984.000000
# mean         -0.000435         -0.020152     0.001007                 0.001269
# std           0.030869          0.140965     0.016017                 0.019733
# min          -1.000000         -1.000000    -0.123558                -0.126568
# 25%          -0.011021         -0.005881    -0.006926                -0.008492
# 50%           0.000277          0.000000     0.000876                 0.000840
# 75%           0.010734          0.005454     0.009708                 0.011632
# max           0.119511          0.049577     0.088741                 0.157457

# %%
from random import gauss
from random import seed
from pandas import Series
from pandas.plotting import autocorrelation_plot
#seed random number generator
seed(1)
#create while series
series = [gauss(0.0, 1.0) for i in range(1000)]
series = Series(series)

# %%
# summary stats
print(series.describe())
# Out:
# count    1000.000000
# mean       -0.013222
# std         1.003685
# min        -2.961214
# 25%        -0.684192
# 50%        -0.010934
# 75%         0.703915
# max         2.737260
# dtype: float64

# %%
df['Gold Investments'].plot()

# %%
df['Other sharesInvestments'].plot()

# %%
df['Oil Investments'].plot()

# %%
#Now we will check if data is stationary or not.
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df['Comp Stock']) # adfuller give us 5 values

# %%
 # just showing the ouput of test_result
print(" The Values given as output by adfuller is : \n 'ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'\n\n",test_result)
# Out:
#  The Values given as output by adfuller is :
#  'ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'
#
#  (-12.473386265908326, 3.207774293088594e-23, 12, 1971, {'1%': -3.4336720887549483, '5%': -2.863007508094813, '10%': -2.567551240570721}, -10649.854659769328)

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(df):
    result=adfuller(df) # same as above ,variable name changed
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary")
    else:
        print("weak evidence against null hypothesis, time series is non-stationary ")

# %%
adfuller_test(df['Comp Stock'])
# Out:
# ADF Test Statistic : -12.473386265908326
# p-value : 3.207774293088594e-23
# #Lags Used : 12
# Number of Observations Used : 1971
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
adfuller_test(df['Other sharesInvestments'])
# Out:
# ADF Test Statistic : -44.84814456404393
# p-value : 0.0
# #Lags Used : 0
# Number of Observations Used : 1983
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
adfuller_test(df['Gold Investments'])
# Out:
# ADF Test Statistic : -15.906853851669037
# p-value : 8.208405770369246e-29
# #Lags Used : 7
# Number of Observations Used : 1976
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
adfuller_test(df['Oil Investments'])
# Out:
# ADF Test Statistic : -45.94216292983993
# p-value : 0.0
# #Lags Used : 0
# Number of Observations Used : 1983
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Gold Investments'])
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Oil Investments'])
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Other sharesInvestments'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Gold Investments'],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Gold Investments'],lags=40,ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Oil Investments'],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Oil Investments'],lags=40,ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Other sharesInvestments'],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Other sharesInvestments'],lags=40,ax=ax2)

# %%
# For non-seasonal data
#p=1, d=1, q=0 or 1
# Usually in seasonal data we avoid arima ,just showing u how to impliment
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(df['Gold Investments'],order=(1,1,1)) # this order is p d q(0 or 1) 
model_fit=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:     D.Gold Investments   No. Observations:                 1983
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                1067.368
# Method:                       css-mle   S.D. of innovations              0.141
# Date:                Thu, 22 Oct 2020   AIC                          -2126.737
# Time:                        14:42:07   BIC                          -2104.367
# Sample:                             1   HQIC                         -2118.519
#
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -1.571e-06   8.43e-06     -0.186      0.852   -1.81e-05     1.5e-05
# ar.L1.D.Gold Investments    -0.0213      0.022     -0.949      0.342      -0.065       0.023
# ma.L1.D.Gold Investments    -0.9981      0.003   -321.150      0.000      -1.004      -0.992
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -46.9103           +0.0000j           46.9103            0.5000
# MA.1            1.0019           +0.0000j            1.0019            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df['forecast']=model_fit.predict(start=1800,end=1982,dynamic=True)
df[['Gold Investments','forecast']].plot(figsize=(12,8))

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(df['Gold Investments'],order=(1, 1, 1),seasonal_order=(1,1,1,12)) #(p,d,q,Shift)
results=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
df['forecast']=results.predict(start=1800,end=1982,dynamic=True)
df[['Gold Investments','forecast']].plot(figsize=(12,8))

# %%
#creating some data to predict future of this.
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-3]+ DateOffset(months=x)for x in range(0,50)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[2:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Oil Investments Gold Investments Comp Stock  \
# 2021-08-13             NaN              NaN        NaN
# 2021-09-13             NaN              NaN        NaN
# 2021-10-13             NaN              NaN        NaN
# 2021-11-13             NaN              NaN        NaN
# 2021-12-13             NaN              NaN        NaN
#
#            Other sharesInvestments forecast
# 2021-08-13                     NaN      NaN
# 2021-09-13                     NaN      NaN
# 2021-10-13                     NaN      NaN
# 2021-11-13                     NaN      NaN
# 2021-12-13                     NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 1984, end = 2166, dynamic= True)  
future_df[['Gold Investments', 'forecast']].plot(figsize=(12, 8))
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
model=ARIMA(df['Oil Investments'],order=(1,1,1)) # this order is p d q(0 or 1) 
model_fit=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:      D.Oil Investments   No. Observations:                 1983
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                4081.134
# Method:                       css-mle   S.D. of innovations              0.031
# Date:                Thu, 22 Oct 2020   AIC                          -8154.268
# Time:                        14:58:52   BIC                          -8131.899
# Sample:                             1   HQIC                         -8146.051
#
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    -1.55e-06   1.17e-06     -1.322      0.186   -3.85e-06    7.48e-07
# ar.L1.D.Oil Investments    -0.0320      0.022     -1.424      0.155      -0.076       0.012
# ma.L1.D.Oil Investments    -0.9999      0.001   -735.329      0.000      -1.003      -0.997
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -31.2893           +0.0000j           31.2893            0.5000
# MA.1            1.0001           +0.0000j            1.0001            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df['forecast']=model_fit.predict(start=1800,end=1982,dynamic=True)
df[['Oil Investments','forecast']].plot(figsize=(12,8))

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(df['Oil Investments'],order=(1, 1, 1),seasonal_order=(1,1,1,12)) #(p,d,q,Shift)
results=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
df['forecast']=results.predict(start=1800,end=1982,dynamic=True)
df[['Oil Investments','forecast']].plot(figsize=(12,8))

# %%
#creating some data to predict future of this.
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-4]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Oil Investments Gold Investments Comp Stock  \
# 2019-05-11             NaN              NaN        NaN
# 2019-06-11             NaN              NaN        NaN
# 2019-07-11             NaN              NaN        NaN
# 2019-08-11             NaN              NaN        NaN
# 2019-09-11             NaN              NaN        NaN
#
#            Other sharesInvestments forecast
# 2019-05-11                     NaN      NaN
# 2019-06-11                     NaN      NaN
# 2019-07-11                     NaN      NaN
# 2019-08-11                     NaN      NaN
# 2019-09-11                     NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 1984, end = 2166, dynamic= True)  
future_df[['Oil Investments', 'forecast']].plot(figsize=(12, 8))
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
model=ARIMA(df['Other sharesInvestments'],order=(1,1,1)) # this order is p d q(0 or 1) 
model_fit=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
model_fit.summary()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:1490: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(-inv(hess)))
# C:\Users\Ruchi\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\Ruchi\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\Ruchi\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  ARIMA Model Results
# =====================================================================================
# Dep. Variable:     D.Other sharesInvestments   No. Observations:                 1983
# Model:                        ARIMA(1, 1, 1)   Log Likelihood                4964.088
# Method:                              css-mle   S.D. of innovations              0.020
# Date:                       Thu, 22 Oct 2020   AIC                          -9920.176
# Time:                               15:00:29   BIC                          -9897.806
# Sample:                                    1   HQIC                         -9911.958
#
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            5.234e-07   2.35e-06      0.223      0.824   -4.08e-06    5.13e-06
# ar.L1.D.Other sharesInvestments    -0.0124      0.022     -0.557      0.577      -0.056       0.031
# ma.L1.D.Other sharesInvestments    -0.9951        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -80.4330           +0.0000j           80.4330            0.5000
# MA.1            1.0050           +0.0000j            1.0050            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df['forecast']=model_fit.predict(start=1800,end=1982,dynamic=True)
df[['Other sharesInvestments','forecast']].plot(figsize=(12,8))

# %%
model=sm.tsa.statespace.SARIMAX(df['Other sharesInvestments'],order=(1, 1, 1),seasonal_order=(1,1,1,12)) #(p,d,q,Shift)
results=model.fit()
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
df['forecast']=results.predict(start=1800,end=1982,dynamic=True)
df[['Other sharesInvestments','forecast']].plot(figsize=(12,8))

# %%
#creating some data to predict future of this.
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[4:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Oil Investments Gold Investments Comp Stock  \
# 2019-06-15             NaN              NaN        NaN
# 2019-07-15             NaN              NaN        NaN
# 2019-08-15             NaN              NaN        NaN
# 2019-09-15             NaN              NaN        NaN
# 2019-10-15             NaN              NaN        NaN
#
#            Other sharesInvestments forecast
# 2019-06-15                     NaN      NaN
# 2019-07-15                     NaN      NaN
# 2019-08-15                     NaN      NaN
# 2019-09-15                     NaN      NaN
# 2019-10-15                     NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 1984, end = 2166, dynamic= True)  
future_df[['Other sharesInvestments', 'forecast']].plot(figsize=(12, 8))
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
